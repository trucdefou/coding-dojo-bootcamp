# %% [markdown]
# Tarea: Arreglar el gráfico (Core)
# Nombre: Luciano Benjamín Recalde Carballo

# %% [markdown]
# #### Carga de datasets

# %%
import pandas as pd

ds_2015 = "data/2015.csv"
ds_2016 = "data/2016.csv"
ds_2017 = "data/2017.csv"
ds_2018 = "data/2018.csv"
ds_2019 = "data/2019.csv"

df_2015 = pd.read_csv(ds_2015)
df_2016 = pd.read_csv(ds_2016)
df_2017 = pd.read_csv(ds_2017)
df_2018 = pd.read_csv(ds_2018)
df_2019 = pd.read_csv(ds_2019)

# %% [markdown]
# #### Analisis de dataset

# %%
# Visualización de cabezera
df_2015.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# #### Informacion de los tipos de variables

# %%
# sacamos la información de la tabla.
df_2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df_2015.shape
# Out:
# (158, 12)

# %% [markdown]
# Tamanho del dataset

# %% [markdown]
# #### Datos estadisticos

# %%
# sacamos datos estadísticos.
df_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# #### Histogramas

# %% [markdown]
# Importamos la libreria para matplotlib y generamos la grafica del histograma

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20, 20))
ax = fig.gca()
df_2015.hist(
    column=[
        "Happiness Score",
        "Economy (GDP per Capita)",
        "Health (Life Expectancy)",
        "Freedom",
    ],
    ax=ax,
    color='blue',
    edgecolor='black',
    alpha=0.8,
)
# Out:
# /tmp/ipykernel_210688/2632945981.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df_2015.hist(
# array([[<Axes: title={'center': 'Happiness Score'}>,
#         <Axes: title={'center': 'Economy (GDP per Capita)'}>],
#        [<Axes: title={'center': 'Health (Life Expectancy)'}>,
#         <Axes: title={'center': 'Freedom'}>]], dtype=object)

# %% [markdown]
# #### Boxplots

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))
ax1 = axes[0][0]
ax2 = axes[0][1]
ax3 = axes[1][0]
ax4 = axes[1][1]
ax1.boxplot(
    df_2015["Happiness Score"],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax1.set_title("Boxplot de Happiness Score")
ax1.set_ylabel("Scores")
ax2.boxplot(
    df_2015["Economy (GDP per Capita)"],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax2.set_title("Boxplot de Economy (GDP per Capita)")
ax2.set_ylabel("Economy (GDP per Capita)")
ax3.boxplot(
    df_2015["Health (Life Expectancy)"],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax3.set_title("Boxplot de Health (Life Expectancy)")
ax3.set_ylabel("Health (Life Expectancy)")
ax4.boxplot(
    df_2015["Freedom"],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax4.set_title("Boxplot de Freedom")
ax4.set_ylabel("Freedom")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# ##### Columna de Felicidad

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
ax1.hist(
    df_2015['Happiness Score'],
    color='blue',
    edgecolor='black',
    alpha=0.8,
)
ax1.set_title(f"Histograma Happiness Score")
ax1.set_xlabel("Hapiness Score")
ax1.set_ylabel("Frecuencia")
ax2.boxplot(
    df_2015['Happiness Score'],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax2.set_title(f"Boxplot Happinnes Score")
ax2.set_ylabel("Hapiness Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# La mayor parte de los paises poseen un Score de felicidad dentro del intervalo {4.5 : 6.5}
#
# El boxplot muestra que la media se encuentra por debajo de la mediana y que existen pocos paises con un nivel de felicidad muy por encima o por debajo de la media

# %% [markdown]
# ##### Columna de PIB per Cápita

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
ax1.hist(
    df_2015['Economy (GDP per Capita)'],
    color='blue',
    edgecolor='black',
    alpha=0.7,
)
ax1.set_title("Histograma Economy (GDP per Capita)")
ax1.set_xlabel("Economy (GDP per Capita)")
ax1.set_ylabel("Frecuencia")
ax2.boxplot(
    df_2015['Economy (GDP per Capita)'],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax2.set_title(f"Boxplot Economy (GDP per Capita)")
ax2.set_ylabel("Economy (GDP per Capita)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Los paises de menor y mayor GDP poseen los menores indices de economia, mientra que aquellos que poseen valores intermedios entre 0,6 y 1,3 aproximadamente, poseen mejores indices de economia.
# El boxplot demuestra que la mediana se encuentra por encime de los valores medios y que los altos indices y bajos indices se encuentran balanceados.

# %% [markdown]
# ##### Columna de Salud

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
ax1.hist(
    df_2015['Health (Life Expectancy)'],
    color='blue',
    edgecolor='black',
    alpha=0.7,
)
ax1.set_title("Histograma Health (Life Expectancy)")
ax1.set_xlabel("Health (Life Expectancy)")
ax1.set_ylabel("Frecuencia")
ax2.boxplot(
    df_2015['Health (Life Expectancy)'],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax2.set_title("Health (Life Expectancy)")
ax2.set_ylabel("Health (Life Expectancy)")

plt.tight_layout()
plt.show()

# %% [markdown]
# En el histograma se observa que existe una alta expectativa de vida para la mayor parte de los paises. Ya que estos se agrupan en mayor medida en valor por encima de 0,5 y menores de 0,9
#
# El boxplot respalda lo mencionado, ya que la mediana en la parte mas superior asi lo indica. Tambien se observa que los bigotes del mismo son asimetricos, siendo mas cortos para los valores superiores y mas largos para los valores inferiores de Expectativa de vida.

# %% [markdown]
# ##### Columna de Freedom

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
ax1.hist(
    df_2015['Freedom'],
    color='blue',
    edgecolor='black',
    alpha=0.7,
)
ax1.set_title("Freedom")
ax1.set_xlabel("Freedom")
ax1.set_ylabel("Frecuencia")
ax2.boxplot(
    df_2015['Freedom'],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax2.set_title("Freedom")
ax2.set_ylabel("Freedom")

plt.tight_layout()
plt.show()

# %% [markdown]
# El histograma muestra que la mayor parte de los paises presentan altos niveles de libertad, ya que la frecuencia es mayor para valores de libertad superiores
# El boxplot en este caso presenta una simetria en los bigotes y una simetria en los rangos intercuartiles. Lo que indica que existe una gran diferencia entre los valores extremos y la media.

# %% [markdown]
# ### Análisis de Dataset 2016

# %%
# Visualización de cabezera
df_2016.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0      Denmark             Western Europe               1            7.526
# 1  Switzerland             Western Europe               2            7.509
# 2      Iceland             Western Europe               3            7.501
# 3       Norway             Western Europe               4            7.498
# 4      Finland             Western Europe               5            7.413
# 5       Canada              North America               6            7.404
# 6  Netherlands             Western Europe               7            7.339
# 7  New Zealand  Australia and New Zealand               8            7.334
# 8    Australia  Australia and New Zealand               9            7.313
# 9       Sweden             Western Europe              10            7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# ...

# %% [markdown]
# #### Información de la tabla.

# %%
df_2016.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Lower Confidence Interval        float64
# Upper Confidence Interval        float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df_2016.shape
# Out:
# (157, 13)

# %% [markdown]
# #### Datos estadísticos

# %%
df_2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %% [markdown]
# #### Histogramas

# %%
fig = plt.figure(figsize=(20, 20))
ax = fig.gca()
df_2016.hist(
    column=[
        "Happiness Score",
        "Economy (GDP per Capita)",
        "Health (Life Expectancy)",
        "Freedom",
    ],
    ax=ax,
    color='blue',
    edgecolor='black',
    alpha=0.8,
)
# Out:
# /tmp/ipykernel_210688/1283908485.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df_2016.hist(
# array([[<Axes: title={'center': 'Happiness Score'}>,
#         <Axes: title={'center': 'Economy (GDP per Capita)'}>],
#        [<Axes: title={'center': 'Health (Life Expectancy)'}>,
#         <Axes: title={'center': 'Freedom'}>]], dtype=object)

# %% [markdown]
# #### Boxplots

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))
ax1 = axes[0][0]
ax2 = axes[0][1]
ax3 = axes[1][0]
ax4 = axes[1][1]
ax1.boxplot(
    df_2016["Happiness Score"],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax1.set_title("Boxplot de Happiness Score")
ax1.set_ylabel("Scores")
ax2.boxplot(
    df_2016["Economy (GDP per Capita)"],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax2.set_title("Boxplot de Economy (GDP per Capita)")
ax2.set_ylabel("Economy (GDP per Capita)")
ax3.boxplot(
    df_2016["Health (Life Expectancy)"],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax3.set_title("Boxplot de Health (Life Expectancy)")
ax3.set_ylabel("Health (Life Expectancy)")
ax4.boxplot(
    df_2016["Freedom"],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax4.set_title("Boxplot de Freedom")
ax4.set_ylabel("Freedom")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# ##### Columna de Felicidad

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
ax1.hist(
    df_2016['Happiness Score'],
    color='blue',
    edgecolor='black',
    alpha=0.7,
)
ax1.set_title("Happiness Score")
ax1.set_xlabel("Happiness Score")
ax1.set_ylabel("Frecuencia")
ax2.boxplot(
    df_2016['Happiness Score'],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax2.set_title("Hapinness Score")
ax2.set_ylabel("Happines Score")

plt.tight_layout()
plt.show()

# %% [markdown]
# Se observa que la felicidad aumento con respecto a 2015
# En el boxplot la dispersion no muy alta

# %% [markdown]
# ##### Columna de PIB Per Cápita

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
ax1.hist(
    df_2015['Economy (GDP per Capita)'],
    color='blue',
    edgecolor='black',
    alpha=0.7,
)
ax1.set_title("Economy (GDP per Capita)")
ax1.set_xlabel("Economy (GDP per Capita)")
ax1.set_ylabel("Frecuencia")
ax2.boxplot(
    df_2015['Economy (GDP per Capita)'],
    notch=False,
    patch_artist=True,
    boxprops=dict(facecolor='blue', color='black')
)
ax2.set_title("Economy (GDP per Capita)")
ax2.set_ylabel("Economy (GDP per Capita)")

plt.tight_layout()
plt.show()

# %% [markdown]
# El grafico es bastante similar al anterior, se observa que la mayor parte de paises posee un GDP per capita superior
# En el boxplot se observa una baja dispersion

# %% [markdown]
# ##### Análisis de columna de salud.

# %%
def plot_HB( # creamos una funcion ya que la misma podria estar siendo llamada varias veces
    df,
    nombre_columna,
    xlabel_hist=None,
    ylabel_hist=None,
    ylabel_boxplot=None,
):
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))
    ax1.hist(
        df[nombre_columna],
        color='blue',
        edgecolor='black',
        alpha=0.7,
    )
    ax1.set_title(f"Histograma {nombre_columna}")
    if xlabel_hist is not None:
        ax1.set_xlabel(xlabel_hist)
    if ylabel_hist is not None:
        ax1.set_ylabel(ylabel_hist)
    ax2.boxplot(
        df[nombre_columna],
        notch=False,
        patch_artist=True,
        boxprops=dict(facecolor='blue', color='black')
    )
    ax2.set_title(f"Boxplot {nombre_columna}")
    if ylabel_boxplot:
        ax2.set_ylabel(ylabel_boxplot)
    plt.tight_layout()
    plt.show()

plot_HB(
    df_2016, 
    "Health (Life Expectancy)",
    "Health (Life Expectancy)",
    "Frecuencia",
    "Health (Life Expectancy)",
)

# %% [markdown]
# Los datos en el histograma están agrupados hacia la derecha, en especifico en el rango 0.5-0.85 aprox, la mayoría de países reporta un alto puntaje en salud.
# El boxplot pequeño indica una mediana más alta. Se observa que la dispersión es baja ya que el tamaño de la caja es pequeño. La mayor parte de los datos entre los curtiles esta entre 0.41 y 0.76

# %% [markdown]
# ##### Columna de Freedom

# %%
plot_HB(
    df_2016, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# En el histograma se observa que los datos están sesgados hacia la derecha, esto quiere decir que la mayor parte de los países reportan un puntaje alto de libertad.
# El boxplot muestra que el rango intercuartil va de 0.26 a 0.48 approx. Se trata de un rango pequeño comparado con los mínimos y máximos, los datos tienen poca dispersión.

# %% [markdown]
# ### Análisis de Dataset 2017

# %%
# Visualización de cabezera
df_2017.head(10)
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
# 5  Netherlands               6            7.377      7.427426     7.326574
# 6       Canada               7            7.316      7.384403     7.247597
# 7  New Zealand               8            7.314      7.379510     7.248490
# 8       Sweden               9            7.284      7.344095     7.223905
# 9    Australia              10            7.284      7.356651     7.211349
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %% [markdown]
# #### Información de la tabla

# %%
# sacamos la información de la tabla.
df_2017.dtypes
# Out:
# Country                           object
# Happiness.Rank                     int64
# Happiness.Score                  float64
# Whisker.high                     float64
# Whisker.low                      float64
# Economy..GDP.per.Capita.         float64
# Family                           float64
# Health..Life.Expectancy.         float64
# Freedom                          float64
# Generosity                       float64
# Trust..Government.Corruption.    float64
# Dystopia.Residual                float64
# dtype: object

# %%
df_2017.shape
# Out:
# (155, 12)

# %% [markdown]
# #### Datos estadísticos

# %%
# sacamos datos estadísticos.
df_2017.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
# Renombramos campos a analizar para que las funciones de elaboración de gráficos funcionen.

df_2017.rename(
    columns={
        "Happiness.Score": "Happiness Score",
        "Economy..GDP.per.Capita.": "Economy (GDP per Capita)",
        "Health..Life.Expectancy.": "Health (Life Expectancy)",
    },
    inplace=True
)

# %% [markdown]
# #### Histogramas

# %%
fig = plt.figure(figsize=(20, 20))
ax = fig.gca()
df_2017.hist(
    column=[
        "Happiness Score",
        "Economy (GDP per Capita)",
        "Health (Life Expectancy)",
        "Freedom",
    ],
    ax=ax,
    color='blue',
    edgecolor='black',
    alpha=0.8,
)
# Out:
# /tmp/ipykernel_210688/801675339.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df_2017.hist(
# array([[<Axes: title={'center': 'Happiness Score'}>,
#         <Axes: title={'center': 'Economy (GDP per Capita)'}>],
#        [<Axes: title={'center': 'Health (Life Expectancy)'}>,
#         <Axes: title={'center': 'Freedom'}>]], dtype=object)

# %% [markdown]
# #### Boxplots

# %%
def plot_B(df):
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
    ax1 = axes[0][0]
    ax2 = axes[0][1]
    ax3 = axes[1][0]
    ax4 = axes[1][1]
    ax1.boxplot(
        df["Happiness Score"],
        notch=False,
        patch_artist=True,
        boxprops=dict(facecolor='blue', color='black')
    )
    ax1.set_title("Boxplot de Happiness Score")
    ax1.set_ylabel("Scores")
    ax2.boxplot(
        df["Economy (GDP per Capita)"],
        notch=False,
        patch_artist=True,
        boxprops=dict(facecolor='blue', color='black')
    )
    ax2.set_title("Boxplot de Economy (GDP per Capita)")
    ax2.set_ylabel("Economy (GDP per Capita)")
    ax3.boxplot(
        df["Health (Life Expectancy)"],
        notch=False,
        patch_artist=True,
        boxprops=dict(facecolor='blue', color='black')
    )
    ax3.set_title("Boxplot de Health (Life Expectancy)")
    ax3.set_ylabel("Health (Life Expectancy)")
    ax4.boxplot(
        df["Freedom"],
        notch=False,
        patch_artist=True,
        boxprops=dict(facecolor='blue', color='black')
    )
    ax4.set_title("Boxplot de Freedom")
    ax4.set_ylabel("Freedom")
    plt.tight_layout()
    plt.show()
plot_B(df_2017)

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# ##### Columna de Felicidad

# %%
plot_HB(df_2017, "Happiness Score", "Hapiness Score", "Frecuencia", "Hapiness Score")

# %% [markdown]
# La mayor parte de los países tiene un Hapiness Score distribuído de forma mas uniforme en comparacion a otros anhos, la mayor cantidad se concentra entre 4.2 a 6.1 aprox.
# El Boxplot muestra que hay una pequeña cantidad de países que tienen o un score muy alto, o muy bajo. Hay baja dispersion de datos.

# %% [markdown]
# ##### Columna de PIB per Cápita

# %%
plot_HB(
    df_2017, 
    "Economy (GDP per Capita)",
    "Economy (GDP per Capita)",
    "Frecuencia",
    "Economy (GDP per Capita)",
)

# %% [markdown]
# En el histograma vemos un sesgo de los datos hacia la derecha, lo que significa que la mayoría de los países reportan que el GDP per cápita influye bastante en la puntuación de felicidad.
# El boxplot muestra que la dispersión no es tan alta, pero sí una pequeña cantidad de valores anómalos.

# %% [markdown]
# ##### Columna de Salud

# %%
plot_HB(
    df_2017, 
    "Health (Life Expectancy)",
    "Health (Life Expectancy)",
    "Frecuencia",
    "Health (Life Expectancy)",
)

# %% [markdown]
# Los datos en el histograma indican sesgo a la derecha, lo que se traduce como que muchos países valoran con una puntuación alta a la salud
# El boxplot es pequeño y posee una mediana más alta indicando lo mencionado previamente. Se observa tambien que la dispersión es baja ya que el tamanho de la caja es pequeña y la mayoría de los datos entre los curtiles esta entre 0.4 y 0.7

# %% [markdown]
# ##### Columna de Freedom

# %%
plot_HB(
    df_2017, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# El histograma muestra que los datos están sesgados hacia la derecha, lo que indica que la mayoría de los países reportan un puntaje alto de libertad.
#
# En el boxplot se ve que el rango intercuartil va de 0.3 a 0.55 approx. Este es un rango pequeño comparado con los mínimos y máximos, se puede decir que los datos tienen poca dispersión.

# %% [markdown]
# ### Análisis de Dataset 2018

# %%
# Visualización de cabezera
df_2018.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %% [markdown]
# #### Información de la tabla

# %%
# sacamos la información de la tabla.
df_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
df_2018.shape
# Out:
# (156, 9)

# %% [markdown]
# #### Datos estadísticos

# %%
# sacamos datos estadísticos.
df_2018.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
# Renombramos campos a analizar para que las funciones de elaboración de gráficos funcionen.

df_2018.rename(
    columns={
        "Score": "Happiness Score",
        "GDP per capita": "Economy (GDP per Capita)",
        "Healthy life expectancy": "Health (Life Expectancy)",
        "Freedom to make life choices": "Freedom",
    },
    inplace=True
)

# %% [markdown]
# #### Histogramas

# %%
def plot_H(df):
    fig = plt.figure(figsize=(20, 15))
    ax = fig.gca()
    df.hist(
        column=[
            "Happiness Score",
            "Economy (GDP per Capita)",
            "Health (Life Expectancy)",
            "Freedom",
        ],
        ax=ax,
        color='blue',
        edgecolor='black',
        alpha=0.7,
    )
plot_H(df_2018)
# Out:
# /tmp/ipykernel_210688/1834633042.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(

# %% [markdown]
# #### Boxplots

# %%
plot_B(df_2018)

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# #### Columna de Felicidad

# %%
plot_HB(df_2018, "Happiness Score", "Hapiness Score", "Frecuencia", "Hapiness Score")

# %% [markdown]
# De la gráfica se puede sacar las siguientes conclusiones:
#
# Distribucion de Hapiness Score distribuído bastante uniforme en comparacion a otros anhos, la mayor cantidad se concentra entre 4.5 a 6 approx.
# El boxplot muestra que hay una pequeña cantidad de países que tienen o un score muy alto, o muy bajo. tambien se ve baja dispersion.

# %% [markdown]
# ##### Columna PIB per Cápita

# %%
plot_HB(
    df_2018, 
    "Economy (GDP per Capita)",
    "Economy (GDP per Capita)",
    "Frecuencia",
    "Economy (GDP per Capita)",
)

# %% [markdown]
# En el histograma, se puede observar una mayor agrupacion de datos hacia el medio, tambien se observa una pequenha mayor cantidad de paises con GDP per capita alta.
# En el boxplot se observa que la dispersión no es muy alta, pero sí una pequeña cantidad de valores anómalos. Ademas se puede visualizar un outlier con un score por encima de 2.0.

# %% [markdown]
# ##### Columna Freedom

# %%
plot_HB(
    df_2018, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# De los gráficos, se sacan las siguientes conclusiones:
#
# El histograma muestra datos sesgados hacia la derecha, la mayoría de los países reportan puntajes altos de libertad.
# El boxplot muestra el rango intercuartil, que va de 0.3 a 0.65 approx. Un rangp pequenho si comparamos con los maximos y minimos, Datos con poca dispersion.

# %% [markdown]
# ### Análisis de Dataset 2019

# %%
# Visualización de cabezera
df_2019.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
# Renombramos campos a analizar para que las funciones de elaboración de gráficos funcionen.

df_2019.rename(
    columns={
        "Score": "Happiness Score",
        "GDP per capita": "Economy (GDP per Capita)",
        "Healthy life expectancy": "Health (Life Expectancy)",
        "Freedom to make life choices": "Freedom"
    },
    inplace=True
)

# %% [markdown]
# #### Información de la tabla

# %%
# sacamos la información de la tabla.
df_2019.dtypes
# Out:
# Overall rank                   int64
# Country or region             object
# Happiness Score              float64
# Economy (GDP per Capita)     float64
# Social support               float64
# Health (Life Expectancy)     float64
# Freedom                      float64
# Generosity                   float64
# Perceptions of corruption    float64
# dtype: object

# %%
df_2019.shape
# Out:
# (156, 9)

# %% [markdown]
# #### Datos Estadísticos

# %%
# sacamos datos estadísticos.
df_2019.describe()
# Out:
#        Overall rank  Happiness Score  Economy (GDP per Capita)  \
# count    156.000000       156.000000                156.000000
# mean      78.500000         5.407096                  0.905147
# std       45.177428         1.113120                  0.398389
# min        1.000000         2.853000                  0.000000
# 25%       39.750000         4.544500                  0.602750
# 50%       78.500000         5.379500                  0.960000
# 75%      117.250000         6.184500                  1.232500
# max      156.000000         7.769000                  1.684000
#
#        Social support  Health (Life Expectancy)     Freedom  Generosity  \
# count      156.000000                156.000000  156.000000  156.000000
# mean         1.208814                  0.725244    0.392571    0.184846
# std          0.299191                  0.242124    0.143289    0.095254
# min          0.000000                  0.000000    0.000000    0.000000
# ...

# %% [markdown]
# #### Histogramas

# %%
plot_H(df_2019)
# Out:
# /tmp/ipykernel_210688/392059924.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(

# %% [markdown]
# #### Boxplots

# %%
plot_B(df_2019)

# %% [markdown]
# #### Análisis Combinado

# %% [markdown]
# ##### Columna de Felicidad

# %%
plot_HB(df_2019, "Happiness Score", "Hapiness Score", "Frecuencia", "Hapiness Score")

# %% [markdown]
# De la gráfica se puede sacar las siguientes conclusiones:
#
# En el histograma Se observa un Happiness score distribuido de manera bastante uniforme, la mayor parte se consentra entre 4.5 y 6 approx.
# En el boxplot se ve una pequenha cantidad de paises con score muy alto o muy bajo. La dispersion no es muy elevada.

# %% [markdown]
# ##### Columna PIB per Cápita

# %%
plot_HB(
    df_2019, 
    "Economy (GDP per Capita)",
    "Economy (GDP per Capita)",
    "Frecuencia",
    "Economy (GDP per Capita)",
)

# %% [markdown]
# El histograma muestra la mayor parte de sus datos a la derecha, esto indica que el GDP per capita es una variable importante a la hora de ser utilizada como indicador de felicidad.
# En el boxplot, se observa una dispersion no demasiado alta, pero si la existencia de datos anomalos.

# %% [markdown]
# ##### Columna de Salud

# %%
plot_HB(
    df_2019, 
    "Health (Life Expectancy)",
    "Health (Life Expectancy)",
    "Frecuencia",
    "Health (Life Expectancy)",
)

# %% [markdown]
# La mayor parte de paises poseen un nivel de expectativa de vida alta, ya que los datos se encuentran sesgados a la derecha
# La otra grafica se trata de un boxplot pequenho como se puede observar con una mediana más alta indicando lo mencionado previamente. La dispersión es baja ya que el tamaño de la caja es pequeña y la mayoría de los datos entre los curtiles esta entre 0.4 y 0.7. La mediana Posee un valor alto. Finalmente, se puede notar un outlier que tal vez sea un error, de un país que reportó una puntuación muy baja, approx 0.0 en salud.

# %%
# Verificamos el outlier para ver que valor es
df_2019.sort_values(by="Health (Life Expectancy)", ascending=True)
# Out:
#      Overall rank         Country or region  Happiness Score  \
# 134           135                 Swaziland            4.212
# 154           155  Central African Republic            3.083
# 143           144                   Lesotho            3.802
# 131           132                      Chad            4.350
# 98             99               Ivory Coast            4.944
# ..            ...                       ...              ...
# 5               6               Switzerland            7.480
# 29             30                     Spain            6.354
# 57             58                     Japan            5.886
# 75             76                 Hong Kong            5.430
# 33             34                 Singapore            6.262
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 134                     0.811           1.149                     0.000
# 154                     0.026           0.000                     0.105
# ...

# %% [markdown]
# Se observa que efectivamente el outlier tiene un valor de 0.0 y corresponde a Switzerland.

# %% [markdown]
# ##### Columna de Freedom

# %%
plot_HB(
    df_2019, 
    "Freedom",
    "Freedom",
    "Frecuencia",
    "Freedom",
)

# %% [markdown]
# Se observan datos sesgados a la derecha, lo que indica un alto nivel de libertad entre la mayor parte de paises
# Segun la grafica del boxplot se observa que el rango intercuartil va de 0.3 a 0.55 approx. Es un rango pequenho comparado con los mínimos y máximos, los datos tienen poca dispersión. También se puede identificar un outlier.

# %%
# Verificamos el outlier para ver que valor es
df_2019.sort_values(by="Freedom", ascending=True)
# Out:
#      Overall rank     Country or region  Happiness Score  \
# 153           154           Afghanistan            3.203
# 155           156           South Sudan            2.853
# 148           149                 Syria            3.462
# 146           147                 Haiti            3.597
# 121           122            Mauritania            4.490
# ..            ...                   ...              ...
# 0               1               Finland            7.769
# 20             21  United Arab Emirates            6.825
# 2               3                Norway            7.554
# 108           109              Cambodia            4.700
# 40             41            Uzbekistan            6.174
#
#      Economy (GDP per Capita)  Social support  Health (Life Expectancy)  \
# 153                     0.350           0.517                     0.361
# 155                     0.306           0.575                     0.295
# ...

# %% [markdown]
# Segun se observa, el outlier en este caso sería Afganistán y tiene un score de libertad de 0.0.
